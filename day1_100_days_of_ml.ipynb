# %% [markdown]
# <a href="https://colab.research.google.com/github/shivam-nayak-ds/100-days-of-machine-learning-from-scratch/blob/main/day1_100_days_of_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income
# ...

# %%
Y = df['median_house_value']
Y.head()
Y = df.isnull().sum()
Y
# Out:
# 0    452600.0
# 1    358500.0
# 2    352100.0
# 3    341300.0
# 4    342200.0
# Name: median_house_value, dtype: float64

# %%
X = (X -X.mean(axis=0))/(X.std(axis=0))
Y = (Y-Y.mean())/Y.std()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2 , random_state = 42)

# %%
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14196   1.267614 -1.367943            0.346470     0.224713        0.211515
# 8267    0.703610 -0.871677            1.617768     0.342057        0.591216
# 17445  -0.454345 -0.455001           -1.957759    -0.338631       -0.490930
# 14265   1.227684 -1.377307            0.584838    -0.556818       -0.405497
# 2271   -0.114945  0.537530            1.141031    -0.116319       -0.253617
# ...          ...       ...                 ...          ...             ...
# 11284   0.803433 -0.866996            0.505382    -0.598530       -0.799436
# 11964   1.067966 -0.754634            0.346470     0.205461        0.076247
# 5390    0.593804 -0.749952            0.584838    -0.245123        0.073874
# 860    -1.193041  0.912070           -1.083741     0.430524        0.140322
# 15795  -1.422636  1.001024            1.856137     0.728926        1.844226
#
#        population  households  median_income
# ...

# %%
Y_train
# Out:
# 14196   -0.899998
# 8267     1.518638
# 17445   -0.296855
# 14265   -0.983190
# 2271    -0.956326
#            ...
# 11284    0.193631
# 11964   -0.945060
# 5390     0.132104
# 860      0.664186
# 15795    1.023819
# Name: median_house_value, Length: 16512, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train , Y_train)
# Out:
# LinearRegression()
