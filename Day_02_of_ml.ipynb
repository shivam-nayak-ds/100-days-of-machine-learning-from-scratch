# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/sample_data/california_housing_test.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
X = df.drop('median_house_value' , axis = 1)

# %%
X.shape
# Out:
# (3000, 8)

# %%
Y = df['median_house_value']

# %%
X.shape
# Out:
# (3000, 8)

# %%
from sklearn.model_selection import train_test_split
X_train ,X_test ,Y_train, Y_test = train_test_split(X , Y , test_size = 0.2 , random_state = 42)

# %%
X_train.shape
# Out:
# (2400, 8)

# %%
Y_train.shape
# Out:
# (2400,)

# %%
X_test.shape
# Out:
# (600, 8)

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, Y_train)
# Out:
# LinearRegression()

# %%
prediction = model.predict(X_test_scaled)

# %%
from sklearn.metrics import r2_score , mean_squared_error , mean_absolute_error
r2 = r2_score(Y_test , prediction)
mse = mean_squared_error(Y_test , prediction)
moe = mean_absolute_error(Y_test , prediction)

print(f'R2 SCORE : {r2}')
print(f'mse : {mse}')
print(f"moe  : {moe}")
# Out:
# R2 SCORE : 0.6358044169850408
# mse : 4586505886.68125
# moe  : 49554.276208268304

# %%
from sklearn.linear_model import Ridge
ridge_model = Ridge(alpha=0.1)
ridge_model.fit(X_train_scaled , Y_train)
# Out:
# Ridge(alpha=0.1)

# %%
from sklearn.metrics import r2_score , mean_absolute_error
r2 = r2_score(Y_test , prediction)
mae = mean_absolute_error(Y_test , prediction)
print(f'r2 score , {r2}')
print(f'mae score , {mae}')
# Out:
# r2 score , 0.6358044169850408
# mae score , 49554.276208268304

# %%
from sklearn.linear_model import Lasso
Lasso_model = Lasso(alpha = 0.1)
Lasso_model.fit(X_train_scaled, Y_train)



from sklearn.metrics import r2_score , mean_absolute_error
r2 = r2_score(Y_test , prediction)
mae = mean_absolute_error(Y_test , prediction)
print(f'r2 score , {r2}')
print(f'mae score , {mae}')
# Out:
# r2 score , 0.6358044169850408
# mae score , 49554.276208268304

# %%
Lasso_model.coef_
# Out:
# array([-88055.02090651, -92207.2843592 ,  14438.51712405, -16762.33885613,
#         40573.14736348, -41313.6144356 ,  22118.11740285,  72704.17908145])
