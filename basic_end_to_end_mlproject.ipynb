# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
df = pd.read_csv('/content/archive (9).zip')
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
df.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
df.drop('salary' , axis = 1 , inplace = True)

# %%
df.drop('sl_no', axis = 1 , inplace = True)

# %%
df.columns
# Out:
# Index(['gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s', 'degree_p',
#        'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p', 'status'],
#       dtype='object')

# %%
df['status'].value_counts()
# Out:
# status
# Placed        148
# Not Placed     67
# Name: count, dtype: int64

# %%
sns.countplot(x= 'status' , data = df)
plt.show()

# %%
nums = ['ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
        'degree_p', 'degree_t', 'workex', 'etest_p']

# %%
sns.countplot(x= 'gender' , data = df)
plt.show()

# %%
df['gender'].value_counts(normalize=True)*100
# Out:
# gender
# M    64.651163
# F    35.348837
# Name: proportion, dtype: float64

# %%
df.dtypes
# Out:
# gender             object
# ssc_p             float64
# ssc_b              object
# hsc_p             float64
# hsc_b              object
# hsc_s              object
# degree_p          float64
# degree_t           object
# workex             object
# etest_p           float64
# specialisation     object
# mba_p             float64
# status             object
# dtype: object

# %%
num_cols = ['ssc_p','hsc_p']

for col in num_cols:
    plt.figure(figsize=(6,4))
    df.groupby('status')[col].mean().plot(kind='bar')
    plt.title(f"Average {col} by Placement Status")
    plt.show()

# %%
num_cols = ['degree_p','etest_p', 'mba_p']

for col in num_cols:
    plt.figure(figsize=(6,4))
    df.groupby('status')[col].mean().plot(kind='bar')
    plt.title(f"Average {col} by Placement Status")
    plt.show()

# %% [markdown]
# Numerical Columns – Short Insights
#
# ssc_p (10th %): high marks - chance of placement is high
#
# hsc_p (12th %): Good students in 12th class are placed
#
# degree_p (Graduation %): Most strong factor high % = high placement
#
# etest_p (Entrance Test %): Better score → better placement probability
#
# mba_p (MBA %): Higher MBA marks student seleceted most.

# %%
df.dtypes
# Out:
# gender             object
# ssc_p             float64
# ssc_b              object
# hsc_p             float64
# hsc_b              object
# hsc_s              object
# degree_p          float64
# degree_t           object
# workex             object
# etest_p           float64
# specialisation     object
# mba_p             float64
# status             object
# dtype: object

# %%
sns.countplot(x='specialisation' , hue = 'status' , data = df)
plt.show()

# %% [markdown]
# Specialzation shows that Mkt&hr student placed more than Mkt&fin , In Mkt&fin only few student in placed.

# %%
sns.countplot(x='workex' , hue = 'status' , data = df)
plt.show()

# %% [markdown]
# No work experience student also got placed , and work experience student also placed but count of no experience is high .

# %%
sns.countplot(x = 'degree_t' , hue = 'status' , data = df)
plt.show()

# %% [markdown]
# Comm and management student are placed more than sci and tech and other degree

# %%
sns.countplot(x='hsc_b' , hue = 'status' , data = df)
plt.show()

# %% [markdown]
# Central board student placement ratio is higher than other state board.

# %%
df.head(3)
# Out:
#   gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p  status
# 0     No     55.0         Mkt&HR  58.80  Placed
# 1    Yes     86.5        Mkt&Fin  66.28  Placed
# 2     No     75.0        Mkt&Fin  57.80  Placed

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['status'] = le.fit_transform(df['status'])

# %%
X = df.drop('status' , axis = 1)
Y = df['status']

# %%
cats_cols = X.select_dtypes(include='object').columns
nums_cols = X.select_dtypes(exclude='object').columns

# %%
print("Categorical Columns:", cats_cols)
print("Numerical Columns:", nums_cols)
# Out:
# Categorical Columns: Index(['gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex',
#        'specialisation'],
#       dtype='object')
# Numerical Columns: Index(['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p'], dtype='object')

# %%
from sklearn.preprocessing import OneHotEncoder , StandardScaler
from sklearn.compose import ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(), cats_cols),
        ('num' , StandardScaler() , nums_cols)
    ]
)

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , Y_train , Y_test = train_test_split(X,Y , test_size = 0.2 , random_state = 42)

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
model = Pipeline(steps =[
    ('preprocess' , preprocessor),
    ('classifer' , LogisticRegression())
])

# %%
model.fit(X_train , Y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('cat', OneHotEncoder(),
#                                                   Index(['gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex',
#        'specialisation'],
#       dtype='object')),
#                                                  ('num', StandardScaler(),
#                                                   Index(['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p'], dtype='object'))])),
#                 ('classifer', LogisticRegression())])

# %%
import joblib
joblib.dump(model, "placement_model.pkl")
# Out:
# ['placement_model.pkl']
